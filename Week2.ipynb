# %% [markdown]
# <a href="https://colab.research.google.com/github/fika-aini/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# accessing my google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/sample_data/kitten01.jpg')
plt.imshow(img)

# %% [markdown]
# OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red) sehingga warna gambar perlu diconvert menjadi warna RGB dengan method cvtColor -> cv.COLOR_BGR2RGB

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %% [markdown]
# Menampilkan citra Grayscale

# %%
img_gray = cv.imread('/content/drive/MyDrive/sample_data/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘gray’

# %%
plt.imshow(img_gray, cmap='gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna
# ‘magma’

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/sample_data/kitten01.jpg',img5)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10)) #ubah0-ubah ukuran sesuai kebutuhan (10,10)
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image
# dengan tipe data int16

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
#perhatikan kooordinat titik-titik pt1 dan pt2
cv.rectangle(black_img, pt1=(384,0), pt2=(510,150), color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2
# yang tertulis pada kode program.

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang
# tertulis pada kode program

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# penambahan garis sesuai koordinat pt1 dan pt2

# %%
cv.line(black_img, pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah
# ditentukan

# %%
black_img2 = np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %% [markdown]
# Reshape array yang telah diinisialisasi

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 menunjukkan tiap titik dibuat 3 channel yang mewakili R, G, B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **Pertanyaan**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16
# dan int32?
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode
# berikut
# from google.colab.patches import cv2_imshow
# from skimage import io
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
#
# **Jawab**
# 1. dengan matplotlib dapat diketahui ukuran panjang dan lebar dari gambar tersebut, sedangkan tanpa matplotlib menampilkan gambar tanpa diketahui ukurannya
# 2. Perbedaan antara tipe data int16 dan int32 terletak pada jumlah bit yang digunakan untuk merepresentasikan setiap nilai pada piksel. Dalam pembuatan black image, penggunaan tipe data int16 atau int32 mungkin tidak memiliki pengaruh yang signifikan pada hasil akhir. Namun, penggunaan tipe data yang lebih lebar seperti int32 dapat memberikan keuntungan jika kita ingin memproses gambar yang memiliki nilai intensitas yang sangat besar, misalnya pada gambar yang diambil dengan kamera dengan tingkat sensitivitas yang tinggi. Dalam kasus tersebut, penggunaan tipe data yang lebih sempit seperti int16 dapat menyebabkan kehilangan informasi pada gambar karena rentang nilai yang terbatas.
# 3. cv2.imshow() digunakan untuk menampilkan gambar di jendela yang secara otomatis sesuai dengan ukuran gambar.
# 4. "skimage.io" untuk bekerja dengan file gambar di library scikit-image, menyediakan antarmuka yang mudah digunakan untuk membaca dan menulis berbagai format file gambar.

# %% [markdown]
# **E. TUGAS**
#
# Berdasarkan praktikum bagian 1 dan 2 kerjakan beberapa tugas berikut :
# 1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga
# berubah?
# 2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!
# 3. Tampilkan image baris ke 20-115, kolom 25-120!
# 4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!
# 5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image.
# disarankan menggunakan bilangan acak/random!
# 6. Tampilkan image dengan posisi terbalik!
#
# Berdasarkan praktikum bagian 3 dan 4 kerjakan beberapa tugas berikut :
# 7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat
# beraktifitas (bukan pasfoto).
# 8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB
# dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!
# 9. Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran
# font, dan warna font yang sesuai keinginan anda.
#
# **Jawaban**
# 1. figsize parameter hanya akan mengubah ukuran gambar dalam inci, tetapi jumlah pikselnya akan tetap sama.
# Untuk mengubah ukuran piksel gambar, perlu menyesuaikan pengaturan dpi gambar. Pengaturan dpi yang lebih tinggi akan meningkatkan jumlah piksel pada gambar, menghasilkan ukuran gambar yang lebih besar dalam piksel, sedangkan pengaturan dpi yang lebih rendah akan mengurangi jumlah piksel pada gambar, sehingga menghasilkan ukuran gambar yang lebih kecil dalam piksel.

# %% [markdown]
# 2. Mengubah image dalam channel Red-Blue

# %%
img = plt.imread('/content/drive/MyDrive/sample_data/kitten01.jpg')

# Create a new image by setting the green channel to zero
img_rb = img.copy()
img_rb[:, :, 1] = 0

# Swap the red and blue channels
img_rb[:, :, [0, 2]] = img_rb[:, :, [2, 0]]

# Display the new image
plt.imshow(img_rb)
plt.show()

# %% [markdown]
# Mengubah image dalam channel Green-Blue

# %%
img = plt.imread('/content/drive/MyDrive/sample_data/kitten01.jpg')

# Create a new image by setting the red channel to zero
img_gb = img.copy()
img_gb[:, :, 0] = 0

# Display the new image
plt.imshow(img_gb)
plt.show()

# %%
img = plt.imread('/content/drive/MyDrive/sample_data/kitten01.jpg')

# Create a new image by setting the red channel to zero
img_gb2 = img.copy()
img_gb2[:, :, 0] = 0

# Swap the green and blue channels
img_gb2[:, :, [1, 2]] = img_gb2[:, :, [2, 1]]

# Display the new image
plt.imshow(img_gb2)
plt.show()

# %% [markdown]
# 3. menampilkan image baris ke 20-115, kolom 25-120

# %%
import matplotlib.image as mpimg

# Load the image using Matplotlib
img = mpimg.imread('/content/drive/MyDrive/sample_data/kitten01.jpg')

# Extract the desired subregion of the image using NumPy array indexing
subimg = img[20:116, 25:121, :]

# Display the subregion of the image using Matplotlib
plt.imshow(subimg)
plt.show()

# %% [markdown]
# 4. menampilkan image baris ke 5-30, semua kolom, channel Red saja

# %%
# Extract the desired subregion of the image using NumPy array indexing
subimg_red = img[5:31, :, 0]

# Display the subregion of the image using Matplotlib
plt.imshow(subimg_red)
plt.show()

# %%
subimg_red2 = img[5:31, :, 0]

# Display the subregion of the image using Matplotlib
plt.imshow(subimg_red2, cmap='Reds')
plt.show()

# %% [markdown]
# mengapa perlu set cmap reds? apabila tanpa set cmap reds, outputnya belum memiliki channel red saja?

# %%
img = mpimg.imread('/content/drive/MyDrive/sample_data/kitten01.jpg')

# Get the size of the image
height, width, channels = img.shape

# Print the size of the image
print('Height:', height)
print('Width:', width)
print('Number of channels:', channels)
# Out:
# Height: 627
# Width: 670
# Number of channels: 3

# %%
# Load the image using Matplotlib
img = mpimg.imread('/content/drive/MyDrive/sample_data/kitten01.jpg')

# Get the values of each channel at pixel (row, col)
row, col = 627, 670
red_value = img[row, col, 0]
green_value = img[row, col, 1]
blue_value = img[row, col, 2]

# Print the values of each channel at pixel (row, col)
print('Red value:', red_value)
print('Green value:', green_value)
print('Blue value:', blue_value)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-43-f53bab84c396> in <module>
#       4 # Get the values of each channel at pixel (row, col)
#       5 row, col = 627, 670
# ----> 6 red_value = img[row, col, 0]
#       7 green_value = img[row, col, 1]
#       8 blue_value = img[row, col, 2]
#
# IndexError: index 627 is out of bounds for axis 0 with size 627

# %% [markdown]
# 5. Membuat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image menggunakan bilangan acak/random

# %%
import numpy as np
import cv2

# Create a black image
img = np.zeros((400, 400, 3), dtype=np.uint8)

# Create 5 random boxes
for i in range(5):
    x, y = np.random.randint(0, 300, size=2)
    w, h = np.random.randint(50, 150, size=2)
    r, g, b = np.random.randint(0, 255, size=3)
    cv2.rectangle(img, (x, y), (x+w, y+h), (r, g, b), -1)

# Display the image
cv2.imshow('Random Boxes', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-5-64dc8bcc4e7d> in <module>
#      10     w, h = np.random.randint(50, 150, size=2)
#      11     r, g, b = np.random.randint(0, 255, size=3)
# ---> 12     cv2.rectangle(img, (x, y), (x+w, y+h), (r, g, b), -1)
#      13
#      14 # Display the image
#
# error: OpenCV(4.6.0) :-1: error: (-5:Bad argument) in function 'rectangle'
# > Overload resolution failed:
# >  - Scalar value for argument 'color' is not numeric
# >  - Scalar value for argument 'color' is not numeric
# >  - Can't parse 'rec'. Expected sequence length 4, got 2
# >  - Can't parse 'rec'. Expected sequence length 4, got 2

# %% [markdown]
# 6. Menampilkan image dengan posisi terbalik

# %%
img = cv.imread('/content/drive/MyDrive/sample_data/kitten01.jpg')
img1 = cv.flip(img,0)
img2 = img
img3 = cv.flip(cv.cvtColor(img, cv.COLOR_BGR2RGB),0)
final_frame = cv.hconcat((img3, img1))
cv2_imshow(final_frame)
print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=1340x627 at 0x7FE5E4AD8B20>

# %% [markdown]
# 7. Membuat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto)

# %%
image = cv.imread('/content/drive/MyDrive/sample_data/image.jpeg')
image2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
cv.rectangle(image2, pt1=(1300,473), pt2=(1380,620), color=(0,255,0), thickness=10)
cv.circle(image2, center=(1340,550), radius=65, color=(255,0,0), thickness=8)
plt.imshow(image2)

# %% [markdown]
# 8. Membuat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten

# %%
img_blue = img3[:, :, 2]
cv.rectangle(img3, pt1=(0,500), pt2=(100,627), color=(0,0,255), thickness=10)
plt.imshow(img_blue)
