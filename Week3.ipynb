# %% [markdown]
# <a href="https://colab.research.google.com/github/fika-aini/PCVK_Genap_2023/blob/main/Week3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# accessing my google drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
#img = cv.imread('/content/drive/MyDrive/sample_data/mandrill.tiff')
img = cv.cvtColor(cv.imread('/content/drive/MyDrive/sample_data/mandrill.tiff'), cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
print(' Mengubah tingkat kecerahan citra ')
print('----------------------------------')
try:
  brightness = int(input('Masukkan nilai kecerahan : '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/sample_data/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#access every pixel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(original[y,x,c] + brightness, 0, 255)

#simple step without for loop
#brightness_image = cv.convertScaleAbs(original, beta = brightness)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra
# ----------------------------------
# Masukkan nilai kecerahan : 50
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FD15B21F610>

# %% [markdown]
# **TUGAS PRAKTIKUM**
# 1. Implementasikan inverse citra pada Google Colaboratory menggunakan formula yang terdapat pada bagian Ulasan Teori

# %%
img_inverse = cv.imread('/content/drive/MyDrive/sample_data/mandrill.tiff')
inverse_img = np.zeros(original.shape, original.dtype)

#access every pixel
for y in range(img_inverse.shape[0] - 1):
  for x in range(img_inverse.shape[1] - 1):
    for c in range(img_inverse.shape[2]):
      inverse_img[y,x,c] = np.clip(255 - img_inverse[y,x,c], 0, 255)

#simple step without for loop
#brightness_image = cv.convertScaleAbs(original, beta = brightness)

final_frame = cv.hconcat((img_inverse, inverse_img))
cv2_imshow(final_frame)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-1f5958c24d31> in <module>
#       6   for x in range(img_inverse.shape[1] - 1):
#       7     for c in range(img_inverse.shape[2]):
# ----> 8       inverse_img[y,x,c] = np.clip(255 - img_inverse[y,x,c], 0, 255)
#       9
#      10 #simple step without for loop
#
# IndexError: index 256 is out of bounds for axis 1 with size 256

# %%
# Read an image
img_inv = cv.cvtColor(cv.imread('/content/drive/MyDrive/sample_data/mandrill.tiff'), cv.COLOR_BGR2RGB)

# get height and width of the image
height, width, _ = img_inv.shape
  
for i in range(0, height - 1):
    for j in range(0, width - 1):
          
        # Get the pixel value
        pixel = img_inv[i, j]
          
        # Negate each channel by 
        # subtracting it from 255
          
        # 1st index contains red pixel
        pixel[0] = 255 - pixel[0]
          
        # 2nd index contains green pixel
        pixel[1] = 255 - pixel[1]
          
        # 3rd index contains blue pixel
        pixel[2] = 255 - pixel[2]
          
        # Store new values in the pixel
        img_inv[i, j] = pixel
  
# Display the negative transformed image
plt.imshow(img)
plt.show()
plt.imshow(img_inv)
plt.show()

# %% [markdown]
# 2. Implementasikan transformasi contrast pada Google Colaboratory menggunakan
# formula yang terdapat pada bagian Ulasan Teori untuk kontras

# %%
print(' Mengubah kontras dan tingkat kecerahan citra ')
print('----------------------------------------------')
try:
  brightness = int(input('Masukkan tingkat kecerahan [-255 - 255]: '))
  contrass = int(input('Masukkan kontras [1.0 - 3.0]: '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/sample_data/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#access every pixel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip((contrass * original[y,x,c]) + brightness, 0, 255)

#simple step without for loop
#brightness_image = cv.convertScaleAbs(original, beta = brightness)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah kontras dan tingkat kecerahan citra
# ----------------------------------
# Masukkan tingkat kecerahan [-255 - 255]: 50
# Masukkan kontras [1.0 - 3.0]: 2
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FD1589433A0>

# %% [markdown]
# 3. Implementasikan transformasi logarithmic brightness pada Google Colaboratory
# menggunakan formula yang terdapat pada bagian Ulasan Teori untuk transformasi
# log

# %%
print(' Mengubah tingkat kecerahan citra dengan Transformasi Log ')
print('----------------------------------------------------------')
try:
  brightness = int(input('Masukkan nilai kecerahan : '))
except ValueError:
  print('Error, not a number')

original = cv.imread('/content/drive/MyDrive/sample_data/female.tiff')
brightness_image = np.zeros(original.shape, original.dtype)

#access every pixel
for y in range(original.shape[0]):
  for x in range(original.shape[1]):
    for c in range(original.shape[2]):
      brightness_image[y,x,c] = np.clip(brightness * np.log(1 + original[y,x,c]), 0, 255)

#simple step without for loop
#brightness_image = cv.convertScaleAbs(original, beta = brightness)

final_frame = cv.hconcat((original, brightness_image))
cv2_imshow(final_frame)
# Out:
#  Mengubah tingkat kecerahan citra dengan Transformasi Log
# ----------------------------------------------------------
# Masukkan nilai kecerahan : 50
# <PIL.Image.Image image mode=RGB size=512x256 at 0x7FD158928220>

# %% [markdown]
# 4. Implementasikan transformasi grayscale menggunakan metode averaging, lightness,
# dan luminance pada Google Colaboratory menggunakan formula yang terdapat pada
# bagian Ulasan Teori
#
#    a. Averaging

# %%
original = cv.cvtColor(cv.imread('/content/drive/MyDrive/sample_data/mandrill.tiff'), cv.COLOR_BGR2RGB)
avg_image = original.copy()

#access every pixel
for y in range(original.shape[2]):
      avg_image[:,:,y] = original.mean(axis=2)

plt.imshow(original)
plt.show()
plt.imshow(avg_image)
plt.show()

# %% [markdown]
# b. Lightness

# %%
original = cv.cvtColor(cv.imread('/content/drive/MyDrive/sample_data/mandrill.tiff'), cv.COLOR_BGR2RGB)
avg_image = original.copy()

#access every pixel
for y in range(original.shape[2]):
      avg_image[:,:,y] = (original.max(axis=2) + original.min(axis=2)) / 2

plt.imshow(original)
plt.show()
plt.imshow(avg_image)
plt.show()

# %% [markdown]
# c. Luminance

# %%
original = cv.cvtColor(cv.imread('/content/drive/MyDrive/sample_data/mandrill.tiff'), cv.COLOR_BGR2RGB)
avg_image = original.copy()

#access every pixel
for y in range(original.shape[2]):
      avg_image[:,:,y] = (0.21 * original[:,:,0]) + (0.72 * original[:,:,1]) + (0.07 * original[:,:,2])

plt.imshow(original)
plt.show()
plt.imshow(avg_image)
plt.show()

# %% [markdown]
# 5. Tampilkanlah warna tertentu pada citra, dan ubah warna lain menjadi grayscale. Misal,
# tampilkan warna biru pada citra masukan dan ubah bagian lain yang tidak berwarna
# biru menjadi grayscale

# %%
import cv2
import numpy as np

# Load the image
img = cv2.imread('/content/drive/MyDrive/sample_data/mandrill.tiff')

# Define the lower and upper bounds of the blue color in HSV
lower_blue = np.array([90,50,50])
upper_blue = np.array([130,255,255])

# Convert the image to HSV
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)

# Create a mask for the blue color
mask = cv2.inRange(hsv, lower_blue, upper_blue)

# Apply the mask to the original image
result = cv2.bitwise_and(img, img, mask=mask)

# Convert the image to grayscale
gray_img = cv2.cvtColor(result, cv2.COLOR_BGR2GRAY)

# Invert the mask to get the non-blue areas of the image
inv_mask = cv2.bitwise_not(mask)

# Create a grayscale version of the non-blue areas of the image
gray_inv = cv2.cvtColor(cv2.bitwise_and(img, img, mask=inv_mask), cv2.COLOR_BGR2GRAY)

# Combine the blue areas and the grayscale non-blue areas
final_result = cv2.addWeighted(gray_img, 1, gray_inv, 1, 0)

# Show the result
cv2_imshow(final_result)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FD15844B640>
